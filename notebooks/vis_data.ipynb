# %% [markdown]
# # 1. Plot from resized dataset

# %%
path = '/home/yifanc3/segmentation/cell_division/results/40epochweights.36-0.06-0.76-iou75.67-results_val/1_pred.npy'
import numpy as np
arr = np.load(path)

# %%
print(arr.shape)
print(np.unique(arr))
# Out:
# (480, 480)
# [  0 255]

# %%
import matplotlib.pyplot as plt
figure = plt.figure(figsize=(10,10))
plt.imshow(arr, cmap='gray')
plt.title('prediction')

# %%
\

# %%
path = '/home/yifanc3/segmentation/cell_division/results/40epochweights.36-0.06-0.76-iou75.67-results_val/1_gt.npy'
arr = np.load(path)
figure = plt.figure(figsize=(10,10))
plt.imshow(arr, cmap='gray')
plt.title('groundtruth')
