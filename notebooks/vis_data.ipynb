# %% [markdown]
# # 1. Plot from resized dataset

# %%
path = '/home/yifanc3/segmentation/cell_division/results/224random_unet_adadelta_80e_norm/weights.60-iou68.40-results-test/'
import numpy as np
from PIL import Image
import os
name = '10_gt.png'
arr = np.array(Image.open(os.path.join(path, name)))*255

# %%
print(arr.shape)
print(np.unique(arr))
# Out:
# (240, 240)
# [0 1]

# %%
import matplotlib.pyplot as plt
name = '5_input.png'
arr = np.array(Image.open(os.path.join(path, name)))*255
figure = plt.figure(figsize=(5,5))
plt.imshow(arr, cmap='gray')
plt.title('prediction')

# %%
name = '5_pred.png'
arr = np.array(Image.open(os.path.join(path, name)))*255
figure = plt.figure(figsize=(5,5))
plt.imshow(arr, cmap='gray')
plt.title('prediction')

# %%
path = '/home/yifanc3/segmentation/cell_division/results/40epochweights.36-0.06-0.76-iou75.67-results_val/1_gt.npy'
arr = np.load(path)
figure = plt.figure(figsize=(10,10))
plt.imshow(arr, cmap='gray')
plt.title('groundtruth')

# %% [markdown]
# # Adjust Brightness

# %%
import cv2
img = cv2.imread('../dataset/DMSO-20min-001-RGB.png') #load rgb image
hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV) #convert it to hsv

for x in range(0, len(hsv)):
    for y in range(0, len(hsv[0])):
        hsv[x, y][2] += value

img = cv2.cvtColor(hsv, cv2.COLOR_HSV2BGR)
cv2.imwrite("image_processed.jpg", img)
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-3-1ef2a3b93b42> in <module>()
#       3 # hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV) #convert it to hsv
#       4
# ----> 5 for x in range(0, len(hsv)):
#       6     for y in range(0, len(hsv[0])):
#       7         hsv[x, y][2] += value
#
# NameError: name 'hsv' is not defined

# %%
import cv2
def increase_brightness(img, value=30):
    hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
    h, s, v = cv2.split(hsv)

    lim = 255 - value
    v[v > lim] = 255
    v[v <= lim] += value

    final_hsv = cv2.merge((h, s, v))
    img = cv2.cvtColor(final_hsv, cv2.COLOR_HSV2BGR)
    return img

# %%
frame = cv2.imread('/home/yifanc3/segmentation/cell_division/dataset/DMSO-20min-001-RGB.png') #load rgb image
frame = increase_brightness(frame, value=20)
# Out:
# errorTraceback (most recent call last)
# <ipython-input-11-a96f4ac0ec1a> in <module>()
#       1 frame = cv2.imread('/home/yifanc3/segmentation/cell_division/dataset/DMSO-20min-001-RGB.png') #load rgb image
# ----> 2 frame = increase_brightness(frame, value=20)
#
# <ipython-input-10-4391445bf080> in increase_brightness(img, value)
#       1 import cv2
#       2 def increase_brightness(img, value=30):
# ----> 3     hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
#       4     h, s, v = cv2.split(hsv)
#       5
#
# error: OpenCV(3.4.1) /io/opencv/modules/imgproc/src/color.cpp:11214: error: (-215) (scn == 3 || scn == 4) && (depth == 0 || depth == 5) in function cvtColor
